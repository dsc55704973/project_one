# %%
import os, glob
import pandas as pd



df = pd.DataFrame()

for f in glob.glob('data_csv/*'):
    #trim company name from csv file name 'company'
    co_name = f.split('/')[1].split('.')[0]
    print(co_name)
    #fill company column with company value
    #df['A'] = 'foo'
    
    data = pd.read_csv(f, index_col=None,header=0)
    data['company'] = co_name
    
    
    df = df.append(data, ignore_index=True)


#path = "/repos/project/project_one/data_csv"

#all_files = glob.glob(os.path.join(path, "/repos/project/project_one/data_csv"))
#df_merged   = pd.concat(df_from_each_files, ignore_index=True)
#df_merged = (pd.read_csv(f, sep=',') for f in all_files)
#df_merged.to_csv( "merged.csv")
# Out:
# BLDP
# DVN
# MRO
# ENPH
# PSX
# NOV
# HAL
# MPC
# KMI
# TERP
# OXY
# RUN
# GPRE
# SEDG
# HES
# VLO
# XOM
# CVX
# OPTT
# BKR
# CSIQ
# FANG
# EOG
# VSLR
# CXO
# COP
# COG
# HFC
# EVA
# BEP
# PXD
# FSLR
# SPWR
# OKE
# APA
# WMB
# AZRE
# SLB
# REGI
# NBL
# ORA
# FTI

# %%
import os, glob
import pandas as pd



df_2 = pd.DataFrame()

for f in glob.glob('data_csv/*'):
    #trim company name from csv file name 'company'
    co_name = f.split('/')[1].split('.')[0]
    print(co_name)
    #fill company column with company value
    #df['A'] = 'foo'
    
    data = pd.read_csv(f, index_col=None,header=0)
    data['company'] = co_name
    
    
    df_2 = df_2.append(data, ignore_index=True)

df_2
#path = "/repos/project/project_one/data_csv"

#all_files = glob.glob(os.path.join(path, "/repos/project/project_one/data_csv"))
#df_merged   = pd.concat(df_from_each_files, ignore_index=True)
#df_merged = (pd.read_csv(f, sep=',') for f in all_files)
#df_merged.to_csv( "merged.csv")
# Out:
# BLDP
# DVN
# MRO
# ENPH
# PSX
# NOV
# HAL
# MPC
# KMI
# TERP
# OXY
# RUN
# GPRE
# SEDG
# HES
# VLO
# XOM
# CVX
# OPTT
# BKR
# CSIQ
# FANG
# EOG
# VSLR
# CXO
# COP
# COG
# HFC
# EVA
# BEP
# PXD
# FSLR
# SPWR
# OKE
# APA
# WMB
# AZRE
# SLB
# REGI
# NBL
# ORA
# FTI
#                   timestamp  users_holding company
# 0       2018-05-02 04:55:20           2070    BLDP
# 1       2018-05-02 06:40:32           2070    BLDP
# 2       2018-05-03 00:37:18           2085    BLDP
# 3       2018-05-03 06:35:37           2085    BLDP
# 4       2018-05-03 06:50:35           2085    BLDP
# ...                     ...            ...     ...
# 807666  2020-07-28 19:43:07           3298     FTI
# 807667  2020-07-28 20:43:06           3298     FTI
# 807668  2020-07-28 21:42:59           3298     FTI
# 807669  2020-07-28 22:43:10           3298     FTI
# 807670  2020-07-28 23:43:19           3298     FTI
#
# [807671 rows x 3 columns]

# %%
df['company'].value_counts()
df
# Out:
#                   timestamp  users_holding company
# 0       2018-05-02 04:55:20           2070    BLDP
# 1       2018-05-02 06:40:32           2070    BLDP
# 2       2018-05-03 00:37:18           2085    BLDP
# 3       2018-05-03 06:35:37           2085    BLDP
# 4       2018-05-03 06:50:35           2085    BLDP
# ...                     ...            ...     ...
# 807666  2020-07-28 19:43:07           3298     FTI
# 807667  2020-07-28 20:43:06           3298     FTI
# 807668  2020-07-28 21:42:59           3298     FTI
# 807669  2020-07-28 22:43:10           3298     FTI
# 807670  2020-07-28 23:43:19           3298     FTI
#
# [807671 rows x 3 columns]

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807671 entries, 0 to 807670
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   timestamp      807671 non-null  datetime64[ns]
#  1   users_holding  807671 non-null  int64
#  2   company        807671 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 18.5+ MB

# %%
df.set_index('timestamp', inplace=True)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                      users_holding company
# timestamp
# 2018-05-02 04:55:20           2070    BLDP
# 2018-05-02 06:40:32           2070    BLDP
# 2018-05-03 00:37:18           2085    BLDP
# 2018-05-03 06:35:37           2085    BLDP
# 2018-05-03 06:50:35           2085    BLDP
# ...                            ...     ...
# 2020-07-28 19:43:07           3298     FTI
# 2020-07-28 20:43:06           3298     FTI
# 2020-07-28 21:42:59           3298     FTI
# 2020-07-28 22:43:10           3298     FTI
# 2020-07-28 23:43:19           3298     FTI
#
# [807671 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['users_holding', 'company'], dtype='object')

# %%
df_per_company=df.pivot(columns='company', values='users_holding')
#df_per_company=df.pivot(columns='company')
#df_per_company.drop(['users_holding'])
#print(type(df_per_company))
print(df_per_company.columns)
avg_per_company=df_per_company.resample('M').mean()
avg_per_company
# Out:
# Index(['APA', 'AZRE', 'BEP', 'BKR', 'BLDP', 'COG', 'COP', 'CSIQ', 'CVX', 'CXO',
#        'DVN', 'ENPH', 'EOG', 'EVA', 'FANG', 'FSLR', 'FTI', 'GPRE', 'HAL',
#        'HES', 'HFC', 'KMI', 'MPC', 'MRO', 'NBL', 'NOV', 'OKE', 'OPTT', 'ORA',
#        'OXY', 'PSX', 'PXD', 'REGI', 'RUN', 'SEDG', 'SLB', 'SPWR', 'TERP',
#        'VLO', 'VSLR', 'WMB', 'XOM'],
#       dtype='object', name='company')
# company              APA         AZRE           BEP          BKR         BLDP  \
# timestamp
# 2018-05-31   1389.116170    64.823161   2026.877743   611.956318  2066.810047
# 2018-06-30   1523.441926    81.169972   2141.893768   612.324363  2121.885269
# 2018-07-31   1542.261644    98.926027   2262.861644   602.204110  2157.010959
# 2018-08-31   1517.298295   100.195467   2610.327195   564.291785  2115.455319
# 2018-09-30   1391.982808    91.895565   2769.464950   541.131429  2901.849570
# 2018-10-31   1316.704607    99.622463   2859.525745   572.328823  2751.768293
# 2018-11-30   1324.737796   105.538248   3036.016690   681.742698  2802.374652
# 2018-12-31   1324.101078   135.412399   3202.862534   745.929919  2702.816712
# 2019-01-31   1343.184641   179.546341   3385.663793   803.222403  2720.344209
# 2019-02-28   1330.481595   217.693721   3701.231240   859.087156  2641.335890
# 2019-03-31   1291.118156   232.368876   4164.593660   993.036023  2674.380403
# 2019-04-30   1377.283688   242.311174   4349.018388   980.779349  2669.404255
# 2019-05-31   1474.354254   243.480501   4500.817549  1041.676880  2783.174095
# 2019-06-30   1451.268428   294.762500   4618.487500  1056.815278  2709.778860
# 2019-07-31   1498.401351   295.010767   4759.962264  1073.641992  2697.983806
# 2019-08-31   1497.963989   312.480000   4896.862069  1081.863448  2857.391967
# 2019-09-30   1518.899301   297.018106   4966.080893  1334.541783  2873.819832
# 2019-10-31   1532.066849   288.125000   5269.083106  1464.308005  2900.046385
# 2019-11-30   1484.628012   286.176383   5425.359281  1492.417040  3048.807808
# 2019-12-31   1692.542857   345.660615   5625.212885  1549.101955  3172.371105
# 2020-01-31   1825.125786   527.389234   5806.386694  1682.585921  4285.960168
# 2018-11-30   900.888734   10394.557880
# 2018-12-31   936.731806   10732.070081
# 2019-01-31   997.318108   11727.733660
# 2019-02-28  1016.621746   12355.570552
# 2019-03-31  1003.533141   12356.054755
# 2019-04-30  1022.207921   12386.642553
# 2019-05-31  1029.810585   13336.821727
# 2019-06-30  1026.523611   13785.988873
# 2019-07-31  1097.382749   13847.654054
# 2019-08-31  1218.633103   14391.344875
# 2019-09-30  1256.086471   15081.548883
# 2019-10-31  1281.558583   15852.377899
# 2019-11-30  1349.040419   16317.281203
# 2019-12-31  1482.899018   17629.416548
# 2020-01-31  1663.141372   20368.352201
# 2020-02-29  1783.894509   24011.121739
# 2020-03-31  1998.654339   53781.301565
# 2020-04-30  2584.604488  117438.005610
# 2020-05-31  2909.649860  155753.910364
# 2020-06-30  3145.354309  167374.189300
# 2020-07-31  3279.442748  165763.216756
#
# [27 rows x 42 columns]

# %%
avg_per_company.plot(kind='line')

# %%
#df.iloc[0:2].plot(kind='bar')
avg_per_company[['VSLR','MRO','XOM']].plot()

# %%
mean = data[['timestamp', 'users_holding']].groupby('timestamp').mean()['users_holding']
median = data[['timestamp', 'users_holding']].groupby('timestamp').median()['users_holding']


statistics_dict={
    'Mean' : mean,
    'Median' : median,
}
summary_statistics=pd.DataFrame(statistics_dict)
#summary of table
summary_statistics
# Out:
#                      Mean  Median
# timestamp
# 2018-05-02 04:50:48   146     146
# 2018-05-02 06:34:58   146     146
# 2018-05-03 00:32:12   146     146
# 2018-05-03 06:30:36   146     146
# 2018-05-03 06:45:34   146     146
# ...                   ...     ...
# 2020-07-28 19:43:07  3298    3298
# 2020-07-28 20:43:06  3298    3298
# 2020-07-28 21:42:59  3298    3298
# 2020-07-28 22:43:10  3298    3298
# 2020-07-28 23:43:19  3298    3298
#
# [19453 rows x 2 columns]

# %%
# df_test=df.index
#df.loc['2018-05-01': '2018-05-31']

# %%
#df.resample('M').mean()

# %%
mean_holdings_df=df.resample('M').mean()
mean_holdings_df
# Out:
#             users_holding
# timestamp
# 2018-05-31    2383.709843
# 2018-06-30    2638.786568
# 2018-07-31    2849.766088
# 2018-08-31    3023.878860
# 2018-09-30    3030.598198
# 2018-10-31    3069.629515
# 2018-11-30    3152.468222
# 2018-12-31    3242.222208
# 2019-01-31    3457.923368
# 2019-02-28    3807.880022
# 2019-03-31    3973.235357
# 2019-04-30    4125.438230
# 2019-05-31    4455.822449
# 2019-06-30    4650.826064
# 2019-07-31    4860.497141
# 2019-08-31    5107.228634
# 2019-09-30    5279.024764
# 2019-10-31    5488.990138
# 2019-11-30    5657.864132
# 2019-12-31    5791.746060
# 2020-01-31    6290.102157
# 2020-02-29    6994.558611
# 2020-03-31   10527.174790
# 2020-04-30   19976.471684
# 2020-05-31   25634.726209
# 2020-06-30   27058.431337
# 2020-07-31   27271.828634

# %%
mean_holdings_df.plot(kind='bar')

# %%
counts.head()
# Out:
# 3442    387
# 173     316
# 323     308
# 178     298
# 207     267
# Name: users_holding, dtype: int64

# %%
#data = data.resample('timeframe').sum()

# %%
data = pd.read_csv(f, index_col=None,header=0)
#pd.read_csv('data_csv',header=0, delim_whitespace=True)
#df.set_index('timestamp', inplace=True)
df.index = pd.to_datetime(df.index)

# %%
#df.reset_index()
#df

# %%
#df.resample('1M').mean()
